# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Preparing Required Frameworks

# %%
# install dependencies: 
# !pip install -U torch==1.5 torchvision==0.6 -f https://download.pytorch.org/whl/cu101/torch_stable.html
# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# install detectron2:
# !pip install detectron2==0.1.3 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.5/index.html

# %%
# !nvidia-smi
# Out:
# Sat Apr 30 03:45:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8    27W / 149W |      3MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import pandas as pd
import cv2
import random
from google.colab.patches import cv2_imshow
import os
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer, ColorMode
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_test_loader
from detectron2.structures import BoxMode
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

# %% [markdown]
# ## Loading Data

# %%
dir = '/content/gdrive/MyDrive/tooth numbering/new dataset/'
df = pd.read_csv(dir + 'new_data.csv')

data_list = df['file_name'].unique()
new_data_list = []
for file_name in data_list:
  name = file_name.split('.')[0]
  quadrant = name.split('_')[-1]
  if quadrant == 'lr' or quadrant == 'll':
      new_data_list.append(file_name)

data_number = len(new_data_list)
data_idx = list(range(data_number))

random.shuffle(new_data_list)

split_idx = int(.85*data_number)
train_list, validation_list = new_data_list[:split_idx], new_data_list[split_idx:]

df_train = df[df['file_name'].isin(train_list)]
df_validation = df[df['file_name'].isin(validation_list)]

df_train.to_csv(dir + 'down/' + 'train.csv', index=False)
df_validation.to_csv(dir +'down/' + 'validation.csv', index=False)

print(data_number)
print(split_idx)
print(len(df_validation))
print(len(df_train))
df_train.head(30)
# Out:
# 1985
# 1687
# 2135
# 12006
#             file_name  width  height  x_min  x_max  y_min  y_max  class_name  \
# 16    U2_OPG_1_ll.jpg    976     384  876.0  963.0   84.0  322.0          31
# 17    U2_OPG_1_ll.jpg    976     384  813.0  904.0   62.0  340.0          32
# 18    U2_OPG_1_ll.jpg    976     384  725.0  825.0   62.0  376.0          33
# 19    U2_OPG_1_ll.jpg    976     384  621.0  735.0   66.0  385.0          34
# 20    U2_OPG_1_ll.jpg    976     384  524.0  673.0   64.0  367.0          35
# 21    U2_OPG_1_ll.jpg    976     384  350.0  573.0   49.0  346.0          36
# 22    U2_OPG_1_ll.jpg    976     384  166.0  386.0   19.0  310.0          37
# 23    U2_OPG_1_ll.jpg    976     384    6.0  205.0    0.0  250.0          38
# 24    U2_OPG_1_lr.jpg    913     403  119.0  339.0   31.0  316.0          47
# 25    U2_OPG_1_lr.jpg    913     403  305.0  516.0   54.0  370.0          46
# 26    U2_OPG_1_lr.jpg    913     403  487.0  618.0   70.0  375.0          45
# 27    U2_OPG_1_lr.jpg    913     403  578.0  690.0   73.0  354.0          44
# 28    U2_OPG_1_lr.jpg    913     403  676.0  768.0   63.0  385.0          43
# 29    U2_OPG_1_lr.jpg    913     403  761.0  849.0   69.0  342.0          42
# 30    U2_OPG_1_lr.jpg    913     403  834.0  910.0   95.0  328.0          41
# 54   U2_OPG_10_lr.jpg    900     486   23.0  182.0   57.0  221.0          48
# 55   U2_OPG_10_lr.jpg    900     486  134.0  396.0    2.0  280.0          47
# 56   U2_OPG_10_lr.jpg    900     486  269.0  551.0   64.0  374.0          46
# 57   U2_OPG_10_lr.jpg    900     486  474.0  627.0  115.0  421.0          45
# 58   U2_OPG_10_lr.jpg    900     486  588.0  706.0  135.0  444.0          44
# 59   U2_OPG_10_lr.jpg    900     486  680.0  762.0  152.0  491.0          43
# 60   U2_OPG_10_lr.jpg    900     486  753.0  837.0  154.0  456.0          42
# 61   U2_OPG_10_lr.jpg    900     486  823.0  891.0  151.0  451.0          41
# 77  U2_OPG_100_ll.jpg    874     413  796.0  862.0  106.0  394.0          31
# 78  U2_OPG_100_ll.jpg    874     413  733.0  804.0  108.0  419.0          32
# 79  U2_OPG_100_ll.jpg    874     413  647.0  744.0  102.0  440.0          33
# 80  U2_OPG_100_ll.jpg    874     413  562.0  675.0   90.0  378.0          34
# 81  U2_OPG_100_ll.jpg    874     413  458.0  584.0   81.0  362.0          35
# 82  U2_OPG_100_ll.jpg    874     413  269.0  492.0   59.0  353.0          36
# 83  U2_OPG_100_ll.jpg    874     413  113.0  345.0   25.0  287.0          37
#
#        image_source
# 16  SBMU University
# 17  SBMU University
# 18  SBMU University
# 19  SBMU University
# 20  SBMU University
# 21  SBMU University
# 22  SBMU University
# 23  SBMU University
# 24  SBMU University
# 25  SBMU University
# 26  SBMU University
# 27  SBMU University
# 28  SBMU University
# 29  SBMU University
# 30  SBMU University
# 54  SBMU University
# 55  SBMU University
# 56  SBMU University
# 57  SBMU University
# 58  SBMU University
# 59  SBMU University
# 60  SBMU University
# 61  SBMU University
# 77  SBMU University
# 78  SBMU University
# 79  SBMU University
# 80  SBMU University
# 81  SBMU University
# 82  SBMU University
# 83  SBMU University

# %% [markdown]
# ## Creating Dataset

# %%
def dataset_builder(dir, flag='None'):
  if flag=='train':
    # print('train data')
    path = os.path.join(dir+'down/', 'train.csv')
    df = pd.read_csv(path)
    df_filenames = df['file_name'].unique()
  elif flag=='validation':
    # print('validation data')
    path = os.path.join(dir+'down/', 'validation.csv')
    df = pd.read_csv(path)
    df_filenames = df['file_name'].unique()
  else:
    print('other data')

  datadict = []
  id = 1
  for filename in df_filenames:
    name = filename.split('.')[0]
    quadrant = name.split('_')[-1]
    if quadrant == 'lr':
      const = 41
    elif quadrant == 'll':
      const = 31

    objs = []
    file_df = df[df['file_name'] == filename]
    for idx, row in file_df.iterrows():
      record = {}
      record['file_name'] = os.path.join(dir, 'crop_imgs', row['file_name'])
      record['image_id'] = id
      record['height'] = row['height']
      record['width'] = row['width']
      
      
      obj = {
            'bbox' : [row['x_min'], row['y_min'], row['x_max'], row['y_max']],
            'bbox_mode' : BoxMode.XYXY_ABS,
            'category_id' : row['class_name'] - const
        }
      objs.append(obj)

    record['annotations'] = objs
    datadict.append(record)
    id += 1
    
  return datadict

# %%
dir = '/content/gdrive/MyDrive/tooth numbering/new dataset/'
data_dict = dataset_builder(dir, 'train')
print(len(data_dict))
# Out:
# 1687

# %%
dir = '/content/gdrive/MyDrive/tooth numbering/new dataset/'
for x in ['train', 'validation']:
  DatasetCatalog.register('numbering_' + x, lambda x=x : dataset_builder(dir, x))
  MetadataCatalog.get('numbering_' + x).set(thing_classes=['1', '2', '3', '4', '5', '6', '7', '8'])

# %%
numbering_metadata = MetadataCatalog.get('numbering_train')
train_dataset = dataset_builder(dir, 'train')

# %% [markdown]
# ## Visualizing some sample annotated data

# %%
for i in random.sample(train_dataset, 5):
  print(i['file_name'])
  img = cv2.imread(i['file_name'])
  visualizer = Visualizer(img[:, :, ::-1], metadata=numbering_metadata, scale=0.5)
  out = visualizer.draw_dataset_dict(i)
  cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2020_02_509_ll.jpg
# <PIL.Image.Image image mode=RGB size=405x194 at 0x7F7768015DD0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate2-00087_ll.jpg
# <PIL.Image.Image image mode=RGB size=339x214 at 0x7F77655B5C10>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2020_02_287_ll.jpg
# <PIL.Image.Image image mode=RGB size=368x206 at 0x7F7765512FD0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2020_02_72_ll.jpg
# <PIL.Image.Image image mode=RGB size=365x235 at 0x7F77654F8B90>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate4-00053_lr.jpg
# <PIL.Image.Image image mode=RGB size=392x183 at 0x7F7765463A10>

# %% [markdown]
# #### Defining a LossEvalHook in order to store train and validation loss:

# %%
from detectron2.engine.hooks import HookBase
from detectron2.evaluation import inference_context
from detectron2.utils.logger import log_every_n_seconds
from detectron2.data import DatasetMapper, build_detection_test_loader
import detectron2.utils.comm as comm
import torch
import time
import datetime
import logging

class LossEvalHook(HookBase):
    def __init__(self, eval_period, model, data_loader):
        self._model = model
        self._period = eval_period
        self._data_loader = data_loader
    
    def _do_loss_eval(self):
        # Copying inference_on_dataset from evaluator.py
        total = len(self._data_loader)
        num_warmup = min(5, total - 1)
            
        start_time = time.perf_counter()
        total_compute_time = 0
        losses = []
        for idx, inputs in enumerate(self._data_loader):            
            if idx == num_warmup:
                start_time = time.perf_counter()
                total_compute_time = 0
            start_compute_time = time.perf_counter()
            if torch.cuda.is_available():
                torch.cuda.synchronize()
            total_compute_time += time.perf_counter() - start_compute_time
            iters_after_start = idx + 1 - num_warmup * int(idx >= num_warmup)
            seconds_per_img = total_compute_time / iters_after_start
            if idx >= num_warmup * 2 or seconds_per_img > 5:
                total_seconds_per_img = (time.perf_counter() - start_time) / iters_after_start
                eta = datetime.timedelta(seconds=int(total_seconds_per_img * (total - idx - 1)))
                log_every_n_seconds(
                    logging.INFO,
                    "Loss on Validation  done {}/{}. {:.4f} s / img. ETA={}".format(
                        idx + 1, total, seconds_per_img, str(eta)
                    ),
                    n=5,
                )
            loss_batch = self._get_loss(inputs)
            losses.append(loss_batch)
        mean_loss = np.mean(losses)
        self.trainer.storage.put_scalar('validation_loss', mean_loss)
        comm.synchronize()

        return losses
            
    def _get_loss(self, data):
        # How loss is calculated on train_loop 
        metrics_dict = self._model(data)
        metrics_dict = {
            k: v.detach().cpu().item() if isinstance(v, torch.Tensor) else float(v)
            for k, v in metrics_dict.items()
        }
        total_losses_reduced = sum(loss for loss in metrics_dict.values())
        return total_losses_reduced
        
        
    def after_step(self):
        next_iter = self.trainer.iter + 1
        is_final = next_iter == self.trainer.max_iter
        if is_final or (self._period > 0 and next_iter % self._period == 0):
            self._do_loss_eval()
        self.trainer.storage.put_scalars(timetest=12)

# %% [markdown]
# #### Initializing model

# %%
from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
class MyTrainer(DefaultTrainer):
  @classmethod
  def build_evaluator(cls, cfg, dataset_name, output_folder=None):
    if output_folder is None:
        os.makedirs("dental_eval", exist_ok=True)
        output_folder = "dental_eval"
    return COCOEvaluator(dataset_name, cfg, False, output_folder)

  def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(-1,LossEvalHook(
            cfg.TEST.EVAL_PERIOD,
            self.model,
            build_detection_test_loader(
                self.cfg,
                self.cfg.DATASETS.TEST[0],
                DatasetMapper(self.cfg,True)
            )
        ))
        return hooks

# %%
cfg = get_cfg()

# cfg.merge_from_file(model_zoo.get_config_file('COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml'))
# cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml")

# cfg.merge_from_file(model_zoo.get_config_file('COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml'))
# cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")

cfg.merge_from_file(model_zoo.get_config_file('COCO-Detection/faster_rcnn_R_50_DC5_3x.yaml'))
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_DC5_3x.yaml")

# cfg.merge_from_file(model_zoo.get_config_file('COCO-Detection/retinanet_R_50_FPN_3x.yaml'))
# cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/retinanet_R_50_FPN_3x.yaml")

cfg.DATASETS.TRAIN = ('numbering_train',)
cfg.DATASETS.TEST = ("numbering_validation",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.001
cfg.SOLVER.WARMUP_ITERS = 400
cfg.SOLVER.MAX_ITER = 700
cfg.SOLVER.STEPS = (450,550,650)
cfg.SOLVER.GAMMA = 0.1
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 8
# cfg.MODEL.RETINANET.NUM_CLASSES = 4
cfg.TEST.EVAL_PERIOD = 200

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = MyTrainer(cfg)
# trainer = DefaultTrainer(cfg)
# Out:
# [04/30 03:46:52 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (4): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#     )
#     (res5): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(2048, 15, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(2048, 60, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=100352, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=9, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=32, bias=True)
#     )
#   )
# )
# [04/30 03:46:56 d2.data.build]: Removed 0 images with no usable annotations. 1687 images left.
# [04/30 03:46:56 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   | category   | #instances   | category   | #instances   |
# |:----------:|:-------------|:-----------|:-------------|:-----------|:-------------|
# |     1      | 1662         | 2          | 1663         | 3          | 1679         |
# |     4      | 1575         | 5          | 1545         | 6          | 1359         |
# |     7      | 1470         | 8          | 1053         |            |              |
# |   total    | 12006        |            |              |            |              |
# [04/30 03:46:56 d2.data.common]: Serializing 1687 elements to byte tensors and concatenating them all ...
# [04/30 03:46:56 d2.data.common]: Serialized dataset takes 1.01 MiB
# [04/30 03:46:56 d2.data.detection_utils]: TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [04/30 03:46:56 d2.data.build]: Using training sampler TrainingSampler
# [04/30 03:47:00 d2.data.detection_utils]: TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [04/30 03:47:00 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   | category   | #instances   | category   | #instances   |
# |:----------:|:-------------|:-----------|:-------------|:-----------|:-------------|
# |     1      | 296          | 2          | 295          | 3          | 292          |
# |     4      | 280          | 5          | 271          | 6          | 237          |
# |     7      | 263          | 8          | 201          |            |              |
# |   total    | 2135         |            |              |            |              |
# [04/30 03:47:00 d2.data.common]: Serializing 298 elements to byte tensors and concatenating them all ...
# [04/30 03:47:00 d2.data.common]: Serialized dataset takes 0.18 MiB

# %% [markdown]
# ## Training

# %%
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# model_final_68d202.pkl: 663MB [00:09, 66.5MB/s]
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (9, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (9,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (32, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (32,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [04/30 03:47:11 d2.engine.train_loop]: Starting training from iteration 0
# [04/30 03:48:24 d2.utils.events]:  eta: 0:42:38  iter: 19  total_loss: 4.094  loss_cls: 2.150  loss_box_reg: 0.967  loss_rpn_cls: 0.761  loss_rpn_loc: 0.275  time: 3.7304  data_time: 0.0591  lr: 0.000048  max_mem: 5849M
# [04/30 03:49:43 d2.utils.events]:  eta: 0:42:24  iter: 39  total_loss: 2.416  loss_cls: 1.184  loss_box_reg: 0.972  loss_rpn_cls: 0.093  loss_rpn_loc: 0.156  time: 3.8232  data_time: 0.0186  lr: 0.000098  max_mem: 5849M
# [04/30 03:51:01 d2.utils.events]:  eta: 0:41:19  iter: 59  total_loss: 2.148  loss_cls: 0.961  loss_box_reg: 0.979  loss_rpn_cls: 0.078  loss_rpn_loc: 0.117  time: 3.8585  data_time: 0.0177  lr: 0.000148  max_mem: 5849M
# [04/30 04:00:36 d2.evaluation.evaluator]: Inference done 82/298. 0.5059 s / img. ETA=0:01:49
# [04/30 04:00:41 d2.evaluation.evaluator]: Inference done 92/298. 0.5080 s / img. ETA=0:01:45
# [04/30 04:00:46 d2.evaluation.evaluator]: Inference done 102/298. 0.5085 s / img. ETA=0:01:40
# [04/30 04:00:52 d2.evaluation.evaluator]: Inference done 112/298. 0.5100 s / img. ETA=0:01:35
# [04/30 04:00:57 d2.evaluation.evaluator]: Inference done 123/298. 0.5083 s / img. ETA=0:01:29
# [04/30 04:01:02 d2.evaluation.evaluator]: Inference done 133/298. 0.5085 s / img. ETA=0:01:24
# [04/30 04:01:07 d2.evaluation.evaluator]: Inference done 143/298. 0.5089 s / img. ETA=0:01:19
# [04/30 04:01:13 d2.evaluation.evaluator]: Inference done 152/298. 0.5127 s / img. ETA=0:01:15
# [04/30 04:01:18 d2.evaluation.evaluator]: Inference done 162/298. 0.5147 s / img. ETA=0:01:10
# [04/30 04:01:23 d2.evaluation.evaluator]: Inference done 171/298. 0.5174 s / img. ETA=0:01:06
# [04/30 04:01:29 d2.evaluation.evaluator]: Inference done 181/298. 0.5190 s / img. ETA=0:01:01
# [04/30 04:01:34 d2.evaluation.evaluator]: Inference done 191/298. 0.5204 s / img. ETA=0:00:55
# [04/30 04:01:39 d2.evaluation.evaluator]: Inference done 200/298. 0.5221 s / img. ETA=0:00:51
# [04/30 04:01:44 d2.evaluation.evaluator]: Inference done 209/298. 0.5241 s / img. ETA=0:00:46
# [04/30 04:01:49 d2.evaluation.evaluator]: Inference done 218/298. 0.5254 s / img. ETA=0:00:42
# [04/30 04:01:54 d2.evaluation.evaluator]: Inference done 227/298. 0.5273 s / img. ETA=0:00:37
# [04/30 04:02:00 d2.evaluation.evaluator]: Inference done 236/298. 0.5288 s / img. ETA=0:00:32
# [04/30 04:02:05 d2.evaluation.evaluator]: Inference done 246/298. 0.5299 s / img. ETA=0:00:27
# [04/30 04:02:10 d2.evaluation.evaluator]: Inference done 255/298. 0.5308 s / img. ETA=0:00:22
# [04/30 04:02:16 d2.evaluation.evaluator]: Inference done 265/298. 0.5313 s / img. ETA=0:00:17
# [04/30 04:02:21 d2.evaluation.evaluator]: Inference done 274/298. 0.5322 s / img. ETA=0:00:12
# [04/30 04:02:26 d2.evaluation.evaluator]: Inference done 284/298. 0.5317 s / img. ETA=0:00:07
# [04/30 04:02:31 d2.evaluation.evaluator]: Inference done 293/298. 0.5325 s / img. ETA=0:00:02
# [04/30 04:02:34 d2.evaluation.evaluator]: Total inference time: 0:02:36.940954 (0.535635 s / img per device, on 1 devices)
# [04/30 04:02:34 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:36 (0.532922 s / img per device, on 1 devices)
# [04/30 04:02:34 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/30 04:02:34 d2.evaluation.coco_evaluation]: Saving results to dental_eval/coco_instances_results.json
# [04/30 04:02:34 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.07s).
# Accumulating evaluation results...
# DONE (t=0.31s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.489
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.789
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.569
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.689
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.689
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.690
# [04/30 04:02:36 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 48.857 | 78.886 | 57.701 |  nan  | 56.916 | 48.995 |
# [04/30 04:02:36 d2.evaluation.coco_evaluation]: Note that some metrics cannot be computed.
# [04/30 04:02:36 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | 1          | 48.520 | 2          | 58.488 | 3          | 45.001 |
# | 4          | 39.876 | 5          | 40.674 | 6          | 57.484 |
# | 7          | 44.747 | 8          | 56.064 |            |        |
# [04/30 04:02:36 d2.engine.defaults]: Evaluation results for numbering_validation in csv format:
# [04/30 04:02:36 d2.evaluation.testing]: copypaste: Task: bbox
# [04/30 04:02:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/30 04:02:36 d2.evaluation.testing]: copypaste: 48.8567,78.8863,57.7013,nan,56.9162,48.9951
# [04/30 04:02:41 detectron2]: Loss on Validation  done 11/298. 0.0000 s / img. ETA=0:01:32
# [04/30 04:02:46 detectron2]: Loss on Validation  done 23/298. 0.0001 s / img. ETA=0:01:48
# [04/30 04:02:51 detectron2]: Loss on Validation  done 36/298. 0.0001 s / img. ETA=0:01:44
# [04/30 04:02:56 detectron2]: Loss on Validation  done 49/298. 0.0001 s / img. ETA=0:01:39
# [04/30 04:03:01 detectron2]: Loss on Validation  done 61/298. 0.0001 s / img. ETA=0:01:35
# [04/30 04:03:06 detectron2]: Loss on Validation  done 73/298. 0.0001 s / img. ETA=0:01:31
# [04/30 04:03:11 detectron2]: Loss on Validation  done 85/298. 0.0001 s / img. ETA=0:01:26
# [04/30 04:03:16 detectron2]: Loss on Validation  done 97/298. 0.0001 s / img. ETA=0:01:22
# [04/30 04:03:22 detectron2]: Loss on Validation  done 110/298. 0.0001 s / img. ETA=0:01:17
# [04/30 04:03:27 detectron2]: Loss on Validation  done 123/298. 0.0001 s / img. ETA=0:01:11
# [04/30 04:03:32 detectron2]: Loss on Validation  done 136/298. 0.0001 s / img. ETA=0:01:06
# [04/30 04:03:37 detectron2]: Loss on Validation  done 148/298. 0.0001 s / img. ETA=0:01:01
# [04/30 04:03:43 detectron2]: Loss on Validation  done 161/298. 0.0001 s / img. ETA=0:00:56
# [04/30 04:03:48 detectron2]: Loss on Validation  done 174/298. 0.0001 s / img. ETA=0:00:50
# [04/30 04:03:53 detectron2]: Loss on Validation  done 187/298. 0.0001 s / img. ETA=0:00:45
# [04/30 04:03:59 detectron2]: Loss on Validation  done 199/298. 0.0001 s / img. ETA=0:00:40
# [04/30 04:04:04 detectron2]: Loss on Validation  done 211/298. 0.0001 s / img. ETA=0:00:36
# [04/30 04:04:10 detectron2]: Loss on Validation  done 223/298. 0.0001 s / img. ETA=0:00:31
# [04/30 04:04:15 detectron2]: Loss on Validation  done 235/298. 0.0001 s / img. ETA=0:00:26
# [04/30 04:04:20 detectron2]: Loss on Validation  done 247/298. 0.0001 s / img. ETA=0:00:21
# [04/30 04:04:25 detectron2]: Loss on Validation  done 259/298. 0.0001 s / img. ETA=0:00:16
# [04/30 04:04:30 detectron2]: Loss on Validation  done 272/298. 0.0001 s / img. ETA=0:00:10
# [04/30 04:04:36 detectron2]: Loss on Validation  done 284/298. 0.0001 s / img. ETA=0:00:05
# [04/30 04:04:41 detectron2]: Loss on Validation  done 296/298. 0.0001 s / img. ETA=0:00:00
# [04/30 04:04:42 d2.utils.events]:  eta: 0:31:48  iter: 199  total_loss: 0.827  loss_cls: 0.334  loss_box_reg: 0.409  loss_rpn_cls: 0.009  loss_rpn_loc: 0.090  validation_loss: 0.794  time: 3.8126  data_time: 0.0183  lr: 0.000498  max_mem: 5849M
d2.evaluation.evaluator]: Total inference pure compute time: 0:02:38 (0.540710 s / img per device, on 1 devices)
# [04/30 04:19:47 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/30 04:19:47 d2.evaluation.coco_evaluation]: Saving results to dental_eval/coco_instances_results.json
# [04/30 04:19:47 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.46s).
# Accumulating evaluation results...
# DONE (t=0.25s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.915
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.653
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.769
# [04/30 04:19:49 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 65.312 | 91.535 | 80.156 |  nan  | 64.029 | 65.329 |
# [04/30 04:19:49 d2.evaluation.coco_evaluation]: Note that some metrics cannot be computed.
# [04/30 04:19:49 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | 1          | 57.373 | 2          | 59.449 | 3          | 65.987 |
# | 4          | 54.240 | 5          | 58.587 | 6          | 80.524 |
# | 7          | 78.321 | 8          | 68.013 |            |        |
# [04/30 04:19:49 d2.engine.defaults]: Evaluation results for numbering_validation in csv format:
# [04/30 04:19:49 d2.evaluation.testing]: copypaste: Task: bbox
# [04/30 04:19:49 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/30 04:19:49 d2.evaluation.testing]: copypaste: 65.3117,91.5351,80.1564,nan,64.0288,65.3288
# [04/30 04:19:53 detectron2]: Loss on Validation  done 11/298. 0.0000 s / img. ETA=0:01:32
# [04/30 04:19:58 detectron2]: Loss on Validation  done 23/298. 0.0000 s / img. ETA=0:01:47
# [04/30 04:20:03 detectron2]: Loss on Validation  done 36/298. 0.0000 s / img. ETA=0:01:43
# [04/30 04:20:09 detectron2]: Loss on Validation  done 49/298. 0.0000 s / img. ETA=0:01:38
# [04/30 04:20:14 detectron2]: Loss on Validation  done 62/298. 0.0000 s / img. ETA=0:01:34
# [04/30 04:20:19 detectron2]: Loss on Validation  done 75/298. 0.0000 s / img. ETA=0:01:29
# [04/30 04:20:24 detectron2]: Loss on Validation  done 87/298. 0.0000 s / img. ETA=0:01:25
# [04/30 04:20:29 detectron2]: Loss on Validation  done 99/298. 0.0000 s / img. ETA=0:01:21
# [04/30 04:20:35 detectron2]: Loss on Validation  done 112/298. 0.0000 s / img. ETA=0:01:15
# [04/30 04:20:40 detectron2]: Loss on Validation  done 125/298. 0.0000 s / img. ETA=0:01:10
# [04/30 04:20:45 detectron2]: Loss on Validation  done 137/298. 0.0000 s / img. ETA=0:01:05
# [04/30 04:20:50 detectron2]: Loss on Validation  done 150/298. 0.0000 s / img. ETA=0:01:00
# [04/30 04:20:56 detectron2]: Loss on Validation  done 163/298. 0.0000 s / img. ETA=0:00:55
# [04/30 04:21:01 detectron2]: Loss on Validation  done 176/298. 0.0000 s / img. ETA=0:00:49
# [04/30 04:21:06 detectron2]: Loss on Validation  done 189/298. 0.0000 s / img. ETA=0:00:44
# [04/30 04:21:11 detectron2]: Loss on Validation  done 200/298. 0.0000 s / img. ETA=0:00:40
# [04/30 04:21:16 detectron2]: Loss on Validation  done 212/298. 0.0000 s / img. ETA=0:00:35
# [04/30 04:21:22 detectron2]: Loss on Validation  done 224/298. 0.0000 s / img. ETA=0:00:30
# [04/30 04:21:27 detectron2]: Loss on Validation  done 236/298. 0.0000 s / img. ETA=0:00:25
# [04/30 04:33:03 d2.utils.events]:  eta: 0:07:32  iter: 579  total_loss: 0.431  loss_cls: 0.126  loss_box_reg: 0.231  loss_rpn_cls: 0.006  loss_rpn_loc: 0.059  validation_loss: 0.669  time: 3.7449  data_time: 0.0301  lr: 0.000010  max_mem: 5849M
# [04/30 04:34:18 d2.data.common]: Serializing 298 elements to byte tensors and concatenating them all ...
# [04/30 04:34:18 d2.data.common]: Serialized dataset takes 0.18 MiB
# [04/30 04:34:18 d2.evaluation.evaluator]: Start inference on 298 images
# [04/30 04:34:25 d2.evaluation.evaluator]: Inference done 11/298. 0.5328 s / img. ETA=0:02:33
# [04/30 04:34:30 d2.evaluation.evaluator]: Inference done 20/298. 0.5453 s / img. ETA=0:02:32
# [04/30 04:34:36 d2.evaluation.evaluator]: Inference done 30/298. 0.5453 s / img. ETA=0:02:26
# [04/30 04:34:41 d2.evaluation.evaluator]: Inference done 40/298. 0.5364 s / img. ETA=0:02:19
# [04/30 04:34:46 d2.evaluation.evaluator]: Inference done 50/298. 0.5309 s / img. ETA=0:02:12
# [04/30 04:34:51 d2.evaluation.evaluator]: Inference done 60/298. 0.5291 s / img. ETA=0:02:06
# [04/30 04:34:57 d2.evaluation.evaluator]: Inference done 70/298. 0.5307 s / img. ETA=0:02:01
# [04/30 04:35:02 d2.evaluation.evaluator]: Inference done 80/298. 0.5298 s / img. ETA=0:01:56
# [04/30 04:35:07 d2.evaluation.evaluator]: Inference done 90/298. 0.5321 s / img. ETA=0:01:51
# [04/30 04:35:13 d2.evaluation.evaluator]: Inference done 100/298. 0.5318 s / img. ETA=0:01:45
# [04/30 04:35:18 d2.evaluation.evaluator]: Inference done 110/298. 0.5325 s / img. ETA=0:01:40
# [04/30 04:35:23 d2.evaluation.evaluator]: Inference done 120/298. 0.5318 s / img. ETA=0:01:35
# [04/30 04:35:29 d2.evaluation.evaluator]: Inference done 130/298. 0.5314 s / img. ETA=0:01:29
# [04/30 04:35:34 d2.evaluation.evaluator]: Inference done 140/298. 0.5310 s / img. ETA=0:01:24
# [04/30 04:35:39 d2.evaluation.evaluator]: Inference done 149/298. 0.5339 s / img. ETA=0:01:19
# [04/30 04:35:44 d2.evaluation.evaluator]: Inference done 158/298. 0.5365 s / img. ETA=0:01:15
# [04/30 04:35:50 d2.evaluation.evaluator]: Inference done 167/298. 0.5391 s / img. ETA=0:01:10
# [04/30 04:35:55 d2.evaluation.evaluator]: Inference done 176/298. 0.5410 s / img. ETA=0:01:06
# [04/30 04:36:00 d2.evaluation.evaluator]: Inference done 185/298. 0.5426 s / img. ETA=0:01:01
# [04/30 04:36:05 d2.evaluation.evaluator]: Inference done 194/298. 0.5445 s / img. ETA=0:00:56
# [04/30 04:36:11 d2.evaluation.evaluator]: Inference done 203/298. 0.5461 s / img. ETA=0:00:52
# [04/30 04:36:16 d2.evaluation.evaluator]: Inference done 212/298. 0.5483 s / img. ETA=0:00:47
# [04/30 04:36:21 d2.evaluation.evaluator]: Inference done 221/298. 0.5502 s / img. ETA=0:00:42
# [04/30 04:36:27 d2.evaluation.evaluator]: Inference done 230/298. 0.5523 s / img. ETA=0:00:37
# [04/30 04:36:32 d2.evaluation.evaluator]: Inference done 239/298. 0.5536 s / img. ETA=0:00:32
# [04/30 04:36:37 d2.evaluation.evaluator]: Inference done 248/298. 0.5549 s / img. ETA=0:00:27
# [04/30 04:36:43 d2.evaluation.evaluator]: Inference done 257/298. 0.5558 s / img. ETA=0:00:22
# [04/30 04:36:48 d2.evaluation.evaluator]: Inference done 266/298. 0.5567 s / img. ETA=0:00:17
# [04/30 04:36:53 d2.evaluation.evaluator]: Inference done 275/298. 0.5574 s / img. ETA=0:00:12
# [04/30 04:36:59 d2.evaluation.evaluator]: Inference done 285/298. 0.5571 s / img. ETA=0:00:07
# [04/30 04:37:04 d2.evaluation.evaluator]: Inference done 294/298. 0.5583 s / img. ETA=0:00:02
# [04/30 04:37:06 d2.evaluation.evaluator]: Total inference time: 0:02:44.406105 (0.561113 s / img per device, on 1 devices)
# [04/30 04:37:06 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:43 (0.558427 s / img per device, on 1 devices)
# [04/30 04:37:06 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/30 04:37:06 d2.evaluation.coco_evaluation]: Saving results to dental_eval/coco_instances_results.json
# [04/30 04:37:06 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.19s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.25s).
# Accumulating evaluation results...
# DONE (t=0.22s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.725
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.885
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.649
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.726
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.794
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.814
# [04/30 04:37:08 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 72.514 | 94.986 | 88.452 |  nan  | 64.908 | 72.558 |
# [04/30 04:37:08 d2.evaluation.coco_evaluation]: Note that some metrics cannot be computed.
# [04/30 04:37:08 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | 1          | 59.846 | 2          | 68.997 | 3          | 73.436 |
# | 4          | 70.338 | 5          | 66.085 | 6          | 83.640 |
# | 7          | 82.825 | 8          | 74.947 |            |        |
# [04/30 04:37:08 d2.engine.defaults]: Evaluation results for numbering_validation in csv format:
# [04/30 04:37:08 d2.evaluation.testing]: copypaste: Task: bbox
# [04/30 04:37:08 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/30 04:37:08 d2.evaluation.testing]: copypaste: 72.5142,94.9863,88.4524,nan,64.9085,72.5584
# [04/30 04:37:12 detectron2]: Loss on Validation  done 11/298. 0.0000 s / img. ETA=0:01:32
# [04/30 04:37:18 detectron2]: Loss on Validation  done 23/298. 0.0000 s / img. ETA=0:01:48
# [04/30 04:37:23 detectron2]: Loss on Validation  done 36/298. 0.0000 s / img. ETA=0:01:44
# [04/30 04:37:28 detectron2]: Loss on Validation  done 49/298. 0.0000 s / img. ETA=0:01:39
# [04/30 04:37:33 detectron2]: Loss on Validation  done 61/298. 0.0000 s / img. ETA=0:01:35
# [04/30 04:37:38 detectron2]: Loss on Validation  done 74/298. 0.0000 s / img. ETA=0:01:30
# [04/30 04:37:44 detectron2]: Loss on Validation  done 87/298. 0.0000 s / img. ETA=0:01:25
# [04/30 04:37:49 detectron2]: Loss on Validation  done 99/298. 0.0000 s / img. ETA=0:01:21
# [04/30 04:37:54 detectron2]: Loss on Validation  done 112/298. 0.0000 s / img. ETA=0:01:16
# [04/30 04:37:59 detectron2]: Loss on Validation  done 125/298. 0.0000 s / img. ETA=0:01:10
# [04/30 04:38:04 detectron2]: Loss on Validation  done 137/298. 0.0000 s / img. ETA=0:01:05
# [04/30 04:38:10 detectron2]: Loss on Validation  done 150/298. 0.0000 s / img. ETA=0:01:00
# [04/30 04:38:15 detectron2]: Loss on Validation  done 162/298. 0.0000 s / img. ETA=0:00:55
# [04/30 04:38:20 detectron2]: Loss on Validation  done 175/298. 0.0000 s / img. ETA=0:00:50
# [04/30 04:38:25 detectron2]: Loss on Validation  done 188/298. 0.0000 s / img. ETA=0:00:44
# [04/30 04:38:31 detectron2]: Loss on Validation  done 200/298. 0.0000 s / img. ETA=0:00:40
# [04/30 04:38:36 detectron2]: Loss on Validation  done 212/298. 0.0000 s / img. ETA=0:00:35
# [04/30 04:38:41 detectron2]: Loss on Validation  done 224/298. 0.0000 s / img. ETA=0:00:30
# [04/30 04:38:47 detectron2]: Loss on Validation  done 236/298. 0.0000 s / img. ETA=0:00:25
# [04/30 04:38:52 detectron2]: Loss on Validation  done 249/298. 0.0000 s / img. ETA=0:00:20
# [04/30 04:38:57 detectron2]: Loss on Validation  done 261/298. 0.0000 s / img. ETA=0:00:15
# [04/30 04:39:02 detectron2]: Loss on Validation  done 273/298. 0.0000 s / img. ETA=0:00:10
# [04/30 04:39:07 detectron2]: Loss on Validation  done 285/298. 0.0000 s / img. ETA=0:00:05
# [04/30 04:39:13 detectron2]: Loss on Validation  done 297/298. 0.0000 s / img. ETA=0:00:00
# [04/30 04:39:14 d2.utils.events]:  eta: 0:06:17  iter: 599  total_loss: 0.392  loss_cls: 0.102  loss_box_reg: 0.231  loss_rpn_cls: 0.004  loss_rpn_loc: 0.056  validation_loss: 0.545  time: 3.7445  data_time: 0.0308  lr: 0.000010  max_mem: 5849M
# [04/30 04:40:24 d2.utils.events]:  eta: 0:05:02  iter: 619  total_loss: 0.397  loss_cls: 0.108  loss_box_reg: 0.220  loss_rpn_cls: 0.003  loss_rpn_loc: 0.060  validation_loss: 0.545  time: 3.7377  data_time: 0.0362  lr: 0.000010  max_mem: 5849M
# [04/30 04:41:39 d2.utils.events]:  eta: 0:03:47  iter: 639  total_loss: 0.403  loss_cls: 0.112  loss_box_reg: 0.220  loss_rpn_cls: 0.004  loss_rpn_loc: 0.060  validation_loss: 0.545  time: 3.7377  data_time: 0.0307  lr: 0.000010  max_mem: 5849M
# [04/30 04:42:55 d2.utils.events]:  eta: 0:02:33  iter: 659  total_loss: 0.409  loss_cls: 0.114  loss_box_reg: 0.225  loss_rpn_cls: 0.007  loss_rpn_loc: 0.063  validation_loss: 0.545  time: 3.7401  data_time: 0.0329  lr: 0.000001  max_mem: 5849M
# [04/30 04:44:11 d2.utils.events]:  eta: 0:01:18  iter: 679  total_loss: 0.419  loss_cls: 0.124  loss_box_reg: 0.224  loss_rpn_cls: 0.004  loss_rpn_loc: 0.064  validation_loss: 0.545  time: 3.7410  data_time: 0.0291  lr: 0.000001  max_mem: 5849M
# [04/30 04:45:32 d2.data.common]: Serializing 298 elements to byte tensors and concatenating them all ...
# [04/30 04:45:32 d2.data.common]: Serialized dataset takes 0.18 MiB
# [04/30 04:45:32 d2.evaluation.evaluator]: Start inference on 298 images
# [04/30 04:45:38 d2.evaluation.evaluator]: Inference done 11/298. 0.5271 s / img. ETA=0:02:31
# [04/30 04:45:43 d2.evaluation.evaluator]: Inference done 20/298. 0.5451 s / img. ETA=0:02:32
# [04/30 04:45:49 d2.evaluation.evaluator]: Inference done 30/298. 0.5439 s / img. ETA=0:02:26
# [04/30 04:45:54 d2.evaluation.evaluator]: Inference done 40/298. 0.5343 s / img. ETA=0:02:18
# [04/30 04:45:59 d2.evaluation.evaluator]: Inference done 50/298. 0.5294 s / img. ETA=0:02:11
# [04/30 04:46:04 d2.evaluation.evaluator]: Inference done 60/298. 0.5281 s / img. ETA=0:02:06
# [04/30 04:46:10 d2.evaluation.evaluator]: Inference done 70/298. 0.5300 s / img. ETA=0:02:01
# [04/30 04:46:15 d2.evaluation.evaluator]: Inference done 80/298. 0.5296 s / img. ETA=0:01:55
# [04/30 04:46:21 d2.evaluation.evaluator]: Inference done 90/298. 0.5312 s / img. ETA=0:01:50
# [04/30 04:46:26 d2.evaluation.evaluator]: Inference done 100/298. 0.5309 s / img. ETA=0:01:45
# [04/30 04:46:31 d2.evaluation.evaluator]: Inference done 110/298. 0.5320 s / img. ETA=0:01:40
# [04/30 04:46:37 d2.evaluation.evaluator]: Inference done 120/298. 0.5311 s / img. ETA=0:01:34
# [04/30 04:46:42 d2.evaluation.evaluator]: Inference done 130/298. 0.5308 s / img. ETA=0:01:29
# [04/30 04:46:47 d2.evaluation.evaluator]: Inference done 140/298. 0.5301 s / img. ETA=0:01:24
# [04/30 04:46:52 d2.evaluation.evaluator]: Inference done 149/298. 0.5333 s / img. ETA=0:01:19
# [04/30 04:46:58 d2.evaluation.evaluator]: Inference done 158/298. 0.5360 s / img. ETA=0:01:15
# [04/30 04:47:03 d2.evaluation.evaluator]: Inference done 167/298. 0.5388 s / img. ETA=0:01:10
# [04/30 04:47:08 d2.evaluation.evaluator]: Inference done 176/298. 0.5408 s / img. ETA=0:01:06
# [04/30 04:47:13 d2.evaluation.evaluator]: Inference done 185/298. 0.5421 s / img. ETA=0:01:01
# [04/30 04:47:19 d2.evaluation.evaluator]: Inference done 194/298. 0.5439 s / img. ETA=0:00:56
# [04/30 04:47:24 d2.evaluation.evaluator]: Inference done 203/298. 0.5455 s / img. ETA=0:00:52
# [04/30 04:47:29 d2.evaluation.evaluator]: Inference done 212/298. 0.5475 s / img. ETA=0:00:47
# [04/30 04:47:35 d2.evaluation.evaluator]: Inference done 221/298. 0.5496 s / img. ETA=0:00:42
# [04/30 04:47:40 d2.evaluation.evaluator]: Inference done 230/298. 0.5515 s / img. ETA=0:00:37
# [04/30 04:47:45 d2.evaluation.evaluator]: Inference done 239/298. 0.5529 s / img. ETA=0:00:32
# [04/30 04:47:51 d2.evaluation.evaluator]: Inference done 248/298. 0.5542 s / img. ETA=0:00:27
# [04/30 04:47:56 d2.evaluation.evaluator]: Inference done 257/298. 0.5551 s / img. ETA=0:00:22
# [04/30 04:48:01 d2.evaluation.evaluator]: Inference done 266/298. 0.5559 s / img. ETA=0:00:17
# [04/30 04:48:06 d2.evaluation.evaluator]: Inference done 275/298. 0.5569 s / img. ETA=0:00:12
# [04/30 04:48:12 d2.evaluation.evaluator]: Inference done 285/298. 0.5566 s / img. ETA=0:00:07
# [04/30 04:48:17 d2.evaluation.evaluator]: Inference done 294/298. 0.5578 s / img. ETA=0:00:02
# [04/30 04:48:20 d2.evaluation.evaluator]: Total inference time: 0:02:44.280719 (0.560685 s / img per device, on 1 devices)
# [04/30 04:48:20 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:43 (0.558016 s / img per device, on 1 devices)
# [04/30 04:48:20 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/30 04:48:20 d2.evaluation.coco_evaluation]: Saving results to dental_eval/coco_instances_results.json
# [04/30 04:48:20 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.52s).
# Accumulating evaluation results...
# DONE (t=0.23s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.727
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.951
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.885
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.727
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.815
# [04/30 04:48:21 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 72.740 | 95.056 | 88.519 |  nan  | 66.423 | 72.726 |
# [04/30 04:48:21 d2.evaluation.coco_evaluation]: Note that some metrics cannot be computed.
# [04/30 04:48:21 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | 1          | 60.850 | 2          | 68.899 | 3          | 73.144 |
# | 4          | 70.455 | 5          | 66.011 | 6          | 84.090 |
# | 7          | 82.746 | 8          | 75.721 |            |        |
# [04/30 04:48:21 d2.engine.defaults]: Evaluation results for numbering_validation in csv format:
# [04/30 04:48:21 d2.evaluation.testing]: copypaste: Task: bbox
# [04/30 04:48:21 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/30 04:48:21 d2.evaluation.testing]: copypaste: 72.7396,95.0563,88.5190,nan,66.4232,72.7260
# [04/30 04:48:26 detectron2]: Loss on Validation  done 11/298. 0.0000 s / img. ETA=0:01:32
# [04/30 04:48:31 detectron2]: Loss on Validation  done 23/298. 0.0000 s / img. ETA=0:01:47
# [04/30 04:48:36 detectron2]: Loss on Validation  done 36/298. 0.0000 s / img. ETA=0:01:43
# [04/30 04:48:41 detectron2]: Loss on Validation  done 49/298. 0.0000 s / img. ETA=0:01:38
# [04/30 04:48:47 detectron2]: Loss on Validation  done 62/298. 0.0000 s / img. ETA=0:01:34
# [04/30 04:48:52 detectron2]: Loss on Validation  done 75/298. 0.0000 s / img. ETA=0:01:29
# [04/30 04:48:57 detectron2]: Loss on Validation  done 87/298. 0.0000 s / img. ETA=0:01:25
# [04/30 04:49:02 detectron2]: Loss on Validation  done 99/298. 0.0000 s / img. ETA=0:01:21
# [04/30 04:49:07 detectron2]: Loss on Validation  done 112/298. 0.0000 s / img. ETA=0:01:15
# [04/30 04:49:12 detectron2]: Loss on Validation  done 125/298. 0.0000 s / img. ETA=0:01:10
# [04/30 04:49:18 detectron2]: Loss on Validation  done 137/298. 0.0000 s / img. ETA=0:01:05
# [04/30 04:49:23 detectron2]: Loss on Validation  done 150/298. 0.0000 s / img. ETA=0:01:00
# [04/30 04:49:28 detectron2]: Loss on Validation  done 163/298. 0.0000 s / img. ETA=0:00:55
# [04/30 04:49:33 detectron2]: Loss on Validation  done 176/298. 0.0000 s / img. ETA=0:00:49
# [04/30 04:49:39 detectron2]: Loss on Validation  done 189/298. 0.0000 s / img. ETA=0:00:44
# [04/30 04:49:44 detectron2]: Loss on Validation  done 200/298. 0.0000 s / img. ETA=0:00:40
# [04/30 04:49:49 detectron2]: Loss on Validation  done 212/298. 0.0000 s / img. ETA=0:00:35
# [04/30 04:49:54 detectron2]: Loss on Validation  done 224/298. 0.0000 s / img. ETA=0:00:30
# [04/30 04:49:59 detectron2]: Loss on Validation  done 236/298. 0.0000 s / img. ETA=0:00:25
# [04/30 04:50:05 detectron2]: Loss on Validation  done 249/298. 0.0000 s / img. ETA=0:00:20
# [04/30 04:50:10 detectron2]: Loss on Validation  done 261/298. 0.0000 s / img. ETA=0:00:15
# [04/30 04:50:15 detectron2]: Loss on Validation  done 273/298. 0.0000 s / img. ETA=0:00:10
# [04/30 04:50:20 detectron2]: Loss on Validation  done 285/298. 0.0000 s / img. ETA=0:00:05
# [04/30 04:50:25 detectron2]: Loss on Validation  done 297/298. 0.0000 s / img. ETA=0:00:00
# [04/30 04:50:26 d2.utils.events]:  eta: 0:00:03  iter: 699  total_loss: 0.402  loss_cls: 0.105  loss_box_reg: 0.221  loss_rpn_cls: 0.003  loss_rpn_loc: 0.062  validation_loss: 0.488  time: 3.7403  data_time: 0.0320  lr: 0.000001  max_mem: 5849M
# [04/30 04:50:26 d2.engine.hooks]: Overall training speed: 697 iterations in 0:43:30 (3.7457 s / it)
# [04/30 04:50:26 d2.engine.hooks]: Total training time: 1:03:08 (0:19:38 on hooks)

# %% [markdown]
# ##Evaluating trained model

# %%
# !cp -v /content/output/* '/content/gdrive/MyDrive/tooth numbering/new dataset/down/result'
# Out:
# '/content/output/events.out.tfevents.1651290420.0698683e9b55.72.0' -> '/content/gdrive/MyDrive/tooth numbering/new dataset/down/result/events.out.tfevents.1651290420.0698683e9b55.72.0'
# '/content/output/last_checkpoint' -> '/content/gdrive/MyDrive/tooth numbering/new dataset/down/result/last_checkpoint'
# '/content/output/metrics.json' -> '/content/gdrive/MyDrive/tooth numbering/new dataset/down/result/metrics.json'
# '/content/output/model_final.pth' -> '/content/gdrive/MyDrive/tooth numbering/new dataset/down/result/model_final.pth'

# %% [markdown]
# #### Ploting train and validation loss

# %%
import json
import matplotlib.pyplot as plt

experiment_folder = '/content/output'

def load_json_arr(json_path):
    lines = []
    with open(json_path, 'r') as f:
        for line in f:
            lines.append(json.loads(line))
    return lines

experiment_metrics = load_json_arr(experiment_folder + '/metrics.json')

plt.plot(
    [x['iteration'] for x in experiment_metrics], 
    [x['total_loss'] for x in experiment_metrics])
plt.plot(
    [x['iteration'] for x in experiment_metrics if 'validation_loss' in x], 
    [x['validation_loss'] for x in experiment_metrics if 'validation_loss' in x])
plt.legend(['total_loss', 'validation_loss'], loc='upper left')
plt.show()

# %% [markdown]
# #### Evaluation on validation dataset

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "/content/output/model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7
predictor = DefaultPredictor(cfg)

# %%
evaluator = COCOEvaluator("numbering_validation", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "numbering_validation")
inference_on_dataset(trainer.model, val_loader, evaluator)
# Out:
# [04/30 04:53:58 d2.data.common]: Serializing 298 elements to byte tensors and concatenating them all ...
# [04/30 04:53:58 d2.data.common]: Serialized dataset takes 0.18 MiB
# [04/30 04:53:58 d2.evaluation.evaluator]: Start inference on 298 images
# [04/30 04:54:04 d2.evaluation.evaluator]: Inference done 11/298. 0.5287 s / img. ETA=0:02:32
# [04/30 04:54:09 d2.evaluation.evaluator]: Inference done 21/298. 0.5377 s / img. ETA=0:02:29
# [04/30 04:54:15 d2.evaluation.evaluator]: Inference done 31/298. 0.5392 s / img. ETA=0:02:24
# [04/30 04:54:20 d2.evaluation.evaluator]: Inference done 41/298. 0.5306 s / img. ETA=0:02:17
# [04/30 04:54:25 d2.evaluation.evaluator]: Inference done 51/298. 0.5272 s / img. ETA=0:02:10
# [04/30 04:54:30 d2.evaluation.evaluator]: Inference done 61/298. 0.5268 s / img. ETA=0:02:05
# [04/30 04:54:36 d2.evaluation.evaluator]: Inference done 71/298. 0.5275 s / img. ETA=0:02:00
# [04/30 04:54:41 d2.evaluation.evaluator]: Inference done 81/298. 0.5280 s / img. ETA=0:01:55
# [04/30 04:54:46 d2.evaluation.evaluator]: Inference done 91/298. 0.5286 s / img. ETA=0:01:49
# [04/30 04:54:52 d2.evaluation.evaluator]: Inference done 101/298. 0.5298 s / img. ETA=0:01:44
# [04/30 04:54:57 d2.evaluation.evaluator]: Inference done 111/298. 0.5302 s / img. ETA=0:01:39
# [04/30 04:55:02 d2.evaluation.evaluator]: Inference done 121/298. 0.5292 s / img. ETA=0:01:34
# [04/30 04:55:08 d2.evaluation.evaluator]: Inference done 131/298. 0.5295 s / img. ETA=0:01:28
# [04/30 04:55:13 d2.evaluation.evaluator]: Inference done 141/298. 0.5286 s / img. ETA=0:01:23
# [04/30 04:55:18 d2.evaluation.evaluator]: Inference done 150/298. 0.5325 s / img. ETA=0:01:19
# [04/30 04:55:23 d2.evaluation.evaluator]: Inference done 159/298. 0.5346 s / img. ETA=0:01:14
# [04/30 04:55:29 d2.evaluation.evaluator]: Inference done 168/298. 0.5376 s / img. ETA=0:01:10
# [04/30 04:55:34 d2.evaluation.evaluator]: Inference done 177/298. 0.5395 s / img. ETA=0:01:05
# [04/30 04:55:39 d2.evaluation.evaluator]: Inference done 186/298. 0.5411 s / img. ETA=0:01:00
# [04/30 04:55:44 d2.evaluation.evaluator]: Inference done 195/298. 0.5428 s / img. ETA=0:00:56
# [04/30 04:55:50 d2.evaluation.evaluator]: Inference done 204/298. 0.5445 s / img. ETA=0:00:51
# [04/30 04:55:55 d2.evaluation.evaluator]: Inference done 213/298. 0.5467 s / img. ETA=0:00:46
# [04/30 04:56:00 d2.evaluation.evaluator]: Inference done 222/298. 0.5489 s / img. ETA=0:00:41
# [04/30 04:56:06 d2.evaluation.evaluator]: Inference done 231/298. 0.5504 s / img. ETA=0:00:37
# [04/30 04:56:11 d2.evaluation.evaluator]: Inference done 240/298. 0.5520 s / img. ETA=0:00:32
# [04/30 04:56:16 d2.evaluation.evaluator]: Inference done 249/298. 0.5533 s / img. ETA=0:00:27
# [04/30 04:56:22 d2.evaluation.evaluator]: Inference done 258/298. 0.5539 s / img. ETA=0:00:22
# [04/30 04:56:27 d2.evaluation.evaluator]: Inference done 267/298. 0.5547 s / img. ETA=0:00:17
# [04/30 04:56:32 d2.evaluation.evaluator]: Inference done 276/298. 0.5557 s / img. ETA=0:00:12
# [04/30 04:56:37 d2.evaluation.evaluator]: Inference done 286/298. 0.5552 s / img. ETA=0:00:06
# [04/30 04:56:43 d2.evaluation.evaluator]: Inference done 295/298. 0.5562 s / img. ETA=0:00:01
# [04/30 04:56:45 d2.evaluation.evaluator]: Total inference time: 0:02:43.835518 (0.559166 s / img per device, on 1 devices)
# [04/30 04:56:45 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:43 (0.556410 s / img per device, on 1 devices)
# [04/30 04:56:45 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/30 04:56:45 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [04/30 04:56:45 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.39s).
# Accumulating evaluation results...
# DONE (t=0.23s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.727
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.951
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.885
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.664
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.727
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.815
# [04/30 04:56:46 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 72.740 | 95.056 | 88.519 |  nan  | 66.423 | 72.726 |
# [04/30 04:56:46 d2.evaluation.coco_evaluation]: Note that some metrics cannot be computed.
# [04/30 04:56:46 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | 1          | 60.850 | 2          | 68.899 | 3          | 73.144 |
# | 4          | 70.455 | 5          | 66.011 | 6          | 84.090 |
# | 7          | 82.746 | 8          | 75.721 |            |        |
# OrderedDict([('bbox',
#               {'AP': 72.73957806449091,
#                'AP-1': 60.849849246222064,
#                'AP-2': 68.89920075821992,
#                'AP-3': 73.14435107515456,
#                'AP-4': 70.4549520125206,
#                'AP-5': 66.01120820557443,
#                'AP-6': 84.09009757424806,
#                'AP-7': 82.74567293377743,
#                'AP-8': 75.72129271021028,
#                'AP50': 95.0563211457902,
#                'AP75': 88.51898602187109,
#                'APl': 72.72603845675013,
#                'APm': 66.42324487951807,
#                'APs': nan})])

# %% [markdown]
# #### Visualizing some outputs

# %%
dataset_dicts = dataset_builder(dir, 'validation')
for d in random.sample(dataset_dicts, 15):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=numbering_metadata, 
                   scale=0.6, 
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    print(d["file_name"])
    cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate1-00064_lr.jpg
# <PIL.Image.Image image mode=RGB size=446x207 at 0x7F76E54357D0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate1-00007_ll.jpg
# <PIL.Image.Image image mode=RGB size=476x247 at 0x7F76E9E42BD0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate2-00074_ll.jpg
# <PIL.Image.Image image mode=RGB size=450x231 at 0x7F76E9E93F10>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2020_02_83_ll.jpg
# <PIL.Image.Image image mode=RGB size=425x211 at 0x7F76E6EFF710>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2020_02_222_lr.jpg
# <PIL.Image.Image image mode=RGB size=451x211 at 0x7F76EC0AABD0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2020_02_247_lr.jpg
# <PIL.Image.Image image mode=RGB size=445x325 at 0x7F76E575A450>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate2-00017_lr.jpg
# <PIL.Image.Image image mode=RGB size=472x182 at 0x7F76E5387D10>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/U2_OPG_147_lr.jpg
# <PIL.Image.Image image mode=RGB size=589x225 at 0x7F76E467EC10>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2021_04 (156)_lr.jpg
# <PIL.Image.Image image mode=RGB size=421x255 at 0x7F76E539EED0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate2-00152_ll.jpg
# <PIL.Image.Image image mode=RGB size=466x258 at 0x7F76E4A89ED0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate1-00002_ll.jpg
# <PIL.Image.Image image mode=RGB size=408x222 at 0x7F76E6F10650>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2021_04 (202)_ll.jpg
# <PIL.Image.Image image mode=RGB size=466x302 at 0x7F76E57516D0>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2021_04 (16)_ll.jpg
# <PIL.Image.Image image mode=RGB size=545x285 at 0x7F76E576B550>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/cate2-00032_lr.jpg
# <PIL.Image.Image image mode=RGB size=467x196 at 0x7F76E6EFB190>
# /content/gdrive/MyDrive/tooth numbering/new dataset/crop_imgs/drsh_2021_04 (237)_lr.jpg
# <PIL.Image.Image image mode=RGB size=475x281 at 0x7F76E9E30B50>
